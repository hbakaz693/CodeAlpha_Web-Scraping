# %% [markdown]
# <a href="https://colab.research.google.com/github/hbakaz693/CodeAlpha_Web-Scraping/blob/main/WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

base_url = "https://books.toscrape.com/catalogue/page-{}.html"

data = []

# 50 pages in BOOKSCRAPER website
for page in range(1, 51):

    url = base_url.format(page)

    response = requests.get(url)

    if response.status_code != 200:
        break

    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("article", class_="product_pod")

    for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text

        data.append({
            "Title": title,
            "Price": price
        })

    print(f"Page {page} récupérée")

#  DataFrame
df = pd.DataFrame(data)

# Save CSV
df.to_csv("books_dataset.csv", index=False)

print(f"Nombre de livres : {len(df)}")
# Out:
# Page 1 récupérée
# Page 2 récupérée
# Page 3 récupérée
# Page 4 récupérée
# Page 5 récupérée
# Page 6 récupérée
# Page 7 récupérée
# Page 8 récupérée
# Page 9 récupérée
# Page 10 récupérée
# Page 11 récupérée
# Page 12 récupérée
# Page 13 récupérée
# Page 14 récupérée
# Page 15 récupérée
# Page 16 récupérée
# Page 17 récupérée
# Page 18 récupérée
# Page 19 récupérée
# Page 20 récupérée
# Page 21 récupérée
# Page 22 récupérée
# Page 23 récupérée
# Page 24 récupérée
# Page 25 récupérée
# Page 26 récupérée
# Page 27 récupérée
# Page 28 récupérée
# Page 29 récupérée
# Page 30 récupérée
# Page 31 récupérée
# Page 32 récupérée
# Page 33 récupérée
# Page 34 récupérée
# Page 35 récupérée
# Page 36 récupérée
# Page 37 récupérée
# Page 38 récupérée
# Page 39 récupérée
# Page 40 récupérée
# Page 41 récupérée
# Page 42 récupérée
# Page 43 récupérée
# Page 44 récupérée
# Page 45 récupérée
# Page 46 récupérée
# Page 47 récupérée
# Page 48 récupérée
# Page 49 récupérée
# Page 50 récupérée
# Nombre de livres : 1000
